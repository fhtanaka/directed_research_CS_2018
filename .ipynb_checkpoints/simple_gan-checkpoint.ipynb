# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import CreditCardDataSet
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    options=glob.glob("*.csv"),
    description='File:',
    value = 'diabetes.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', index=2, options=('creditcard.csv', 'data.csv', 'diabetes.csv'), value='diabetes…

# %%
file_name=files_dropdown.value
if file_name == "data.csv":
    message = "Breast Cancer Wisconsin (Diagnostic) Data Set"
    class_name = "diagnosis"
    values_names = {0: "Benign", 1: "Malignant"}
    class_len = 33
elif file_name == "creditcard.csv":
    message = "Credit Card Fraud Detection"
    class_name = "Class"
    values_names = {0: "No Frauds", 1: "Frauds"}
    class_len = 31
elif file_name == "diabetes.csv":
    message="Pima Indians Diabetes Database"
    class_name = "Outcome"
    values_names = {0: "Normal", 1: "Diabets"}
    class_len = 9
else:
     exit()

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.002
#lr= 0.0002
d_steps = 1
batch_size = 5
num_epochs = 1000
print_interval = 50
num_test_samples = 16
loss = nn.BCELoss()

# %%
discriminator = DiscriminatorNet(class_len)
generator = GeneratorNet(class_len)
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
test_noise = noise(num_test_samples)
database = CreditCardDataSet (csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)

num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        if (n_batch) % print_interval == 0:
            filename = "results/" + file_name[:-4] + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
            print(filename)
            file = open(filename, "w")
            print("Discriminator error: ", d_error)
            print("Generator error: ", g_error)
            print("")

            file.write("Discriminator error: " + str(d_error) + "\n")
            file.write("Generator error: " + str(g_error) + "\n")
            file.write("Points: " + str(fake_data) + "\n\n\n")
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_0.txt
# Discriminator error:  tensor(0.9371, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7047, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/0_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(13.3773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/0_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(34.8761, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/0_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(47.3865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  1
# results/diabetes/1_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/1_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.6252, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/1_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(35.7600, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/1_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.6663, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2
# results/diabetes/2_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(51.5210, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/2_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(43.4877, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/2_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/2_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.6464, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  3
# results/diabetes/3_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/3_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/3_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.4639, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/3_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(41.2060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  4
# results/diabetes/4_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/4_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.3175, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/4_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(43.9190, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/4_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.4190, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  5
# results/diabetes/5_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.1470, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/5_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/5_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/5_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  6
# results/diabetes/6_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(29.7270, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/6_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(44.9216, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/6_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/6_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  7
# results/diabetes/7_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/7_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.6428, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/7_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/7_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(44.6620, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  8
# results/diabetes/8_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.3942, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/8_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(32.2065, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/8_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/8_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.1092, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  9
# results/diabetes/9_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(61.4225, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/9_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.3075, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/9_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(44.6692, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/9_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(44.8751, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  10
# results/diabetes/10_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(34.2981, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/10_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(57.7901, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# results/diabetes/10_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(37.4195, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/10_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  11
# results/diabetes/11_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/11_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/11_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(52.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/11_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(35.8220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  12
# results/diabetes/12_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(34.0308, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/12_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/12_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(58.1322, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/12_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.4975, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  13
# results/diabetes/13_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/13_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.8322, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/13_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(31.3611, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/13_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(52.1890, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  14
# results/diabetes/14_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(37.5781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/14_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/14_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.1839, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/14_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.0966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  15
# results/diabetes/15_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/15_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.0660, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/15_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(43.0041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/15_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(34.0451, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  16
# results/diabetes/16_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(38.2755, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/16_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/16_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(37.8947, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/16_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(35.1070, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  17
# results/diabetes/17_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.1484, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/17_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.7077, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/17_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/17_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(43.9021, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  18
# results/diabetes/18_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/18_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/18_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(41.6542, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/18_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.4197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  19
# results/diabetes/19_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(47.4016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/19_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.4782, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/19_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(44.2765, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/19_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(64.4222, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  20
# results/diabetes/20_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(31.4800, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/20_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(47.7488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/20_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(61.7390, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/20_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(34.9562, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# Epoch  21
# results/diabetes/21_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(48.0415, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/21_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/21_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/21_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(57.3090, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  22
# results/diabetes/22_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(53.9793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/22_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.5659, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/22_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(31.9556, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/22_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  23
# results/diabetes/23_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(36.3155, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/23_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(42.7094, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/23_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/23_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  24
# results/diabetes/24_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(40.9828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/24_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.2390, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/24_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.5970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/24_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  25
# results/diabetes/25_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/25_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(49.3639, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/25_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(63.2776, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/25_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(33.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  26
# results/diabetes/26_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.4002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/26_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(49.4164, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/26_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/26_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(51.3744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  27
# results/diabetes/27_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/27_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(48.3449, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/27_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/27_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(58.5701, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  28
# results/diabetes/28_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(58.7457, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/28_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.5377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/28_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(46.4173, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/28_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(37.5192, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  29
# results/diabetes/29_0.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(39.2789, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/29_50.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(35.8413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/29_100.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(48.5773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# results/diabetes/29_150.txt
# Discriminator error:  tensor(27.6310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(27.6310, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch