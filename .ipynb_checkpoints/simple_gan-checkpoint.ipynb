# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import CreditCardDataSet
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    options=glob.glob("*.csv"),
    description='File:',
    value = 'diabetes.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', index=3, options=('creditcard.csv', 'data.csv', 'file_path.csv', 'diabetes.csv',…

# %%
file_name=files_dropdown.value
if file_name == "data.csv":
    message = "Breast Cancer Wisconsin (Diagnostic) Data Set"
    class_name = "diagnosis"
    values_names = {0: "Benign", 1: "Malignant"}
    class_len = 33
elif file_name == "creditcard.csv":
    message = "Credit Card Fraud Detection"
    class_name = "Class"
    values_names = {0: "No Frauds", 1: "Frauds"}
    class_len = 31
elif file_name == "diabetes.csv":
    message="Pima Indians Diabetes Database"
    class_name = "Outcome"
    values_names = {0: "Normal", 1: "Diabets"}
    class_len = 9
else:
     exit()

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
d_steps = 1
batch_size = 5
num_epochs = 5000
print_interval = 100
num_test_samples = 16
loss = nn.BCELoss()

# %%
discriminator = DiscriminatorNet(class_len)
generator = GeneratorNet(class_len)
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
test_noise = noise(num_test_samples)
database = CreditCardDataSet (csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)

num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + file_name[:-4] + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    flt_d_error = d_error
    flt_g_error = g_error
    print("Discriminator error: ", flt_d_error)
    print("Generator error: ", flt_g_error)
    print("")

    file.write("Discriminator error: " + str(flt_d_error) + "\n")
    file.write("Generator error: " + str(flt_g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    d_error_plt.append(flt_d_error)
    g_error_plt.append(flt_g_error)
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_153.txt
# Discriminator error:  tensor(2.1555, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.1240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  1
# results/diabetes/1_153.txt
# Discriminator error:  tensor(0.4892, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9032, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2
# results/diabetes/2_153.txt
# Discriminator error:  tensor(1.7907, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7775, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  3
# results/diabetes/3_153.txt
# Discriminator error:  tensor(0.5564, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9680, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  4
# results/diabetes/4_153.txt
# Discriminator error:  tensor(0.3556, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2395, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  5
# results/diabetes/5_153.txt
# Discriminator error:  tensor(0.7980, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8355, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  6
# results/diabetes/6_153.txt
# Discriminator error:  tensor(4.4372, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.9292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  7
# results/diabetes/7_153.txt
# Discriminator error:  tensor(0.4572, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.5337, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  8
# results/diabetes/8_153.txt
# Discriminator error:  tensor(1.3930, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7190, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  9
# results/diabetes/9_153.txt
# Discriminator error:  tensor(0.6269, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  10
# results/diabetes/10_153.txt
# Discriminator error:  tensor(1.7753, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9637, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  11
# results/diabetes/11_153.txt
# Discriminator error:  tensor(0.5703, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6505, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  12
# results/diabetes/12_153.txt
# Discriminator error:  tensor(1.9796, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6180, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  13
# results/diabetes/13_153.txt
# Discriminator error:  tensor(2.4559, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8020, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  14
# results/diabetes/14_153.txt
# Discriminator error:  tensor(0.6525, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  15
# results/diabetes/15_153.txt
# Discriminator error:  tensor(0.8535, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.3491, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  16
# results/diabetes/16_153.txt
# Discriminator error:  tensor(1.9006, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6432, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  17
# results/diabetes/17_153.txt
# Discriminator error:  tensor(1.8259, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.2333, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  18
# results/diabetes/18_153.txt
# Discriminator error:  tensor(1.6057, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.8252, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  19
# results/diabetes/19_153.txt
# Discriminator error:  tensor(0.6221, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2570, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  20
# results/diabetes/20_153.txt
# Discriminator error:  tensor(0.9327, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.1365, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  21
# results/diabetes/21_153.txt
# Discriminator error:  tensor(1.5641, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.3746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  22
# results/diabetes/22_153.txt
# Discriminator error:  tensor(0.6173, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7084, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  23
# results/diabetes/23_153.txt
# Discriminator error:  tensor(0.6083, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6916, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  24
# results/diabetes/24_153.txt
# Discriminator error:  tensor(1.1474, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4658, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  25
# results/diabetes/25_153.txt
# Discriminator error:  tensor(0.3921, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.5490, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  26
# results/diabetes/26_153.txt
# Discriminator error:  tensor(1.0658, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8996, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  27
# results/diabetes/27_153.txt
# Discriminator error:  tensor(1.0235, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2802, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  28
# results/diabetes/28_153.txt
# Discriminator error:  tensor(0.7655, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.3293, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  29
# results/diabetes/29_153.txt
# Discriminator error:  tensor(1.0277, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  30
# results/diabetes/30_153.txt
# Discriminator error:  tensor(2.2702, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2549, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  31
# results/diabetes/31_153.txt
# Discriminator error:  tensor(0.9053, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8305, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  32
# results/diabetes/32_153.txt
# Discriminator error:  tensor(0.9119, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0168, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  33
# results/diabetes/33_153.txt
# Discriminator error:  tensor(0.7201, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9862, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  34
# results/diabetes/34_153.txt
# Discriminator error:  tensor(0.7469, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0328, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  35
# results/diabetes/35_153.txt
# Discriminator error:  tensor(1.6662, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  36
# results/diabetes/36_153.txt
# Discriminator error:  tensor(1.3912, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7402, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  37
# results/diabetes/37_153.txt
# Discriminator error:  tensor(0.4816, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.1233, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  38
# results/diabetes/38_153.txt
# Discriminator error:  tensor(0.8575, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  39
# results/diabetes/39_153.txt
# Discriminator error:  tensor(1.7699, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6510, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  40
# results/diabetes/40_153.txt
# Discriminator error:  tensor(0.8449, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8658, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  41
# results/diabetes/41_153.txt
# Discriminator error:  tensor(1.8962, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8235, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  42
# results/diabetes/42_153.txt
# Discriminator error:  tensor(1.0031, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6950, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  43
# results/diabetes/43_153.txt
# Discriminator error:  tensor(1.7658, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2367, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  44
# results/diabetes/44_153.txt
# Discriminator error:  tensor(1.3094, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4082, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  45
# results/diabetes/45_153.txt
# Discriminator error:  tensor(0.8162, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(2.0413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  46
# results/diabetes/46_153.txt
# Discriminator error:  tensor(1.7503, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.4180, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  47
# results/diabetes/47_153.txt
# Discriminator error:  tensor(4.4550, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8593, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  48
# results/diabetes/48_153.txt
# Discriminator error:  tensor(1.1142, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0366, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  49
# results/diabetes/49_153.txt
# Discriminator error:  tensor(1.1059, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.5361, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  50
# results/diabetes/50_153.txt
# Discriminator error:  tensor(0.8560, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0942, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  51
# results/diabetes/51_153.txt
# Discriminator error:  tensor(0.9518, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9754, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  52
# results/diabetes/52_153.txt
# Discriminator error:  tensor(1.2126, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.6323, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  53
# results/diabetes/53_153.txt
# Discriminator error:  tensor(0.9960, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7968, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  54
# results/diabetes/54_153.txt
# Discriminator error:  tensor(1.0685, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.3285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  55
# results/diabetes/55_153.txt
# Discriminator error:  tensor(1.2988, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.1470, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  56
# results/diabetes/56_153.txt
# Discriminator error:  tensor(0.9450, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.3296, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  57
# results/diabetes/57_153.txt
# Discriminator error:  tensor(1.5369, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6763, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  58
# results/diabetes/58_153.txt
# Discriminator error:  tensor(1.0184, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  59
# results/diabetes/59_153.txt
# Discriminator error:  tensor(1.1456, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  60
# results/diabetes/60_153.txt
# Discriminator error:  tensor(1.3673, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9754, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  61
# results/diabetes/61_153.txt
# Discriminator error:  tensor(1.5265, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.3156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  62
# results/diabetes/62_153.txt
# Discriminator error:  tensor(1.1271, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.6183, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  63
# results/diabetes/63_153.txt
# Discriminator error:  tensor(1.4355, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9446, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  64
# results/diabetes/64_153.txt
# Discriminator error:  tensor(1.5014, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5456, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  65
# results/diabetes/65_153.txt
# Discriminator error:  tensor(1.3767, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  66
# results/diabetes/66_153.txt
# Discriminator error:  tensor(1.5879, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8955, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  67
# results/diabetes/67_153.txt
# Discriminator error:  tensor(1.0499, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  68
# results/diabetes/68_153.txt
# Discriminator error:  tensor(1.4222, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7739, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  69
# results/diabetes/69_153.txt
# Discriminator error:  tensor(1.3469, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8455, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  70
# results/diabetes/70_153.txt
# Discriminator error:  tensor(0.9372, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8127, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  71
# results/diabetes/71_153.txt
# Discriminator error:  tensor(1.6977, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6960, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  72
# results/diabetes/72_153.txt
# Discriminator error:  tensor(1.1973, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  73
# results/diabetes/73_153.txt
# Discriminator error:  tensor(0.9160, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7750, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  74
# results/diabetes/74_153.txt
# Discriminator error:  tensor(1.4513, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  75
# results/diabetes/75_153.txt
# Discriminator error:  tensor(0.9897, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7467, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  76
# results/diabetes/76_153.txt
# Discriminator error:  tensor(1.4455, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7711, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  77
# results/diabetes/77_153.txt
# Discriminator error:  tensor(1.5717, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7091, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  78
# results/diabetes/78_153.txt
# Discriminator error:  tensor(1.6785, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2333, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  79
# results/diabetes/79_153.txt
# Discriminator error:  tensor(1.3671, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8868, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  80
# results/diabetes/80_153.txt
# Discriminator error:  tensor(1.2510, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  81
# results/diabetes/81_153.txt
# Discriminator error:  tensor(1.2794, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9055, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  82
# results/diabetes/82_153.txt
# Discriminator error:  tensor(1.5509, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4406, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  83
# results/diabetes/83_153.txt
# Discriminator error:  tensor(1.0080, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9042, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  84
# results/diabetes/84_153.txt
# Discriminator error:  tensor(1.3882, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.2939, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  85
# results/diabetes/85_153.txt
# Discriminator error:  tensor(1.3070, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  86
# results/diabetes/86_153.txt
# Discriminator error:  tensor(1.5040, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6366, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  87
# results/diabetes/87_153.txt
# Discriminator error:  tensor(1.3775, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6783, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  88
# results/diabetes/88_153.txt
# Discriminator error:  tensor(1.4887, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  89
# results/diabetes/89_153.txt
# Discriminator error:  tensor(0.9823, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8670, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  90
# results/diabetes/90_153.txt
# Discriminator error:  tensor(1.1006, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6698, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  91
# results/diabetes/91_153.txt
# Discriminator error:  tensor(1.3995, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8057, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  92
# results/diabetes/92_153.txt
# Discriminator error:  tensor(1.3691, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  93
# results/diabetes/93_153.txt
# Discriminator error:  tensor(1.3556, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7087, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  94
# results/diabetes/94_153.txt
# Discriminator error:  tensor(1.4662, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  95
# results/diabetes/95_153.txt
# Discriminator error:  tensor(1.0613, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4385, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  96
# results/diabetes/96_153.txt
# Discriminator error:  tensor(1.1454, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0536, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  97
# results/diabetes/97_153.txt
# Discriminator error:  tensor(1.0291, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9686, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  98
# results/diabetes/98_153.txt
# Discriminator error:  tensor(0.8633, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9982, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  99
# results/diabetes/99_153.txt
# Discriminator error:  tensor(1.5154, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6985, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  100
# results/diabetes/100_153.txt
# Discriminator error:  tensor(1.7830, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  101
# results/diabetes/101_153.txt
# Discriminator error:  tensor(1.2298, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2992, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  102
# results/diabetes/102_153.txt
# Discriminator error:  tensor(2.2964, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5897, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  103
# results/diabetes/103_153.txt
# Discriminator error:  tensor(1.3759, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  104
# results/diabetes/104_153.txt
# Discriminator error:  tensor(1.2442, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7720, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  105
# results/diabetes/105_153.txt
# Discriminator error:  tensor(1.2631, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8392, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  106
# results/diabetes/106_153.txt
# Discriminator error:  tensor(1.3216, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8199, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  107
# results/diabetes/107_153.txt
# Discriminator error:  tensor(1.4447, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6194, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  108
# results/diabetes/108_153.txt
# Discriminator error:  tensor(1.5440, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  109
# results/diabetes/109_153.txt
# Discriminator error:  tensor(1.1848, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7306, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  110
# results/diabetes/110_153.txt
# Discriminator error:  tensor(1.8351, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  111
# results/diabetes/111_153.txt
# Discriminator error:  tensor(1.2080, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  112
# results/diabetes/112_153.txt
# Discriminator error:  tensor(0.8336, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9921, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  113
# results/diabetes/113_153.txt
# Discriminator error:  tensor(1.3621, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9333, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  114
# results/diabetes/114_153.txt
# Discriminator error:  tensor(2.3466, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7931, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  115
# results/diabetes/115_153.txt
# Discriminator error:  tensor(1.2741, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  116
# results/diabetes/116_153.txt
# Discriminator error:  tensor(1.5914, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  117
# results/diabetes/117_153.txt
# Discriminator error:  tensor(1.3636, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9194, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  118
# results/diabetes/118_153.txt
# Discriminator error:  tensor(1.3661, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  119
# results/diabetes/119_153.txt
# Discriminator error:  tensor(1.4178, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  120
# results/diabetes/120_153.txt
# Discriminator error:  tensor(1.1992, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  121
# results/diabetes/121_153.txt
# Discriminator error:  tensor(1.8496, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  122
# results/diabetes/122_153.txt
# Discriminator error:  tensor(1.1061, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2472, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  123
# results/diabetes/123_153.txt
# Discriminator error:  tensor(1.2141, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7308, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  124
# results/diabetes/124_153.txt
# Discriminator error:  tensor(1.1779, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  125
# results/diabetes/125_153.txt
# Discriminator error:  tensor(1.5036, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8463, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  126
# results/diabetes/126_153.txt
# Discriminator error:  tensor(1.4774, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5780, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  127
# results/diabetes/127_153.txt
# Discriminator error:  tensor(1.7870, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7073, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  128
# results/diabetes/128_153.txt
# Discriminator error:  tensor(1.2255, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8982, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  129
# results/diabetes/129_153.txt
# Discriminator error:  tensor(1.1922, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9056, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  130
# results/diabetes/130_153.txt
# Discriminator error:  tensor(1.1167, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  131
# results/diabetes/131_153.txt
# Discriminator error:  tensor(1.3933, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  132
# results/diabetes/132_153.txt
# Discriminator error:  tensor(1.0265, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9128, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  133
# results/diabetes/133_153.txt
# Discriminator error:  tensor(1.4707, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4631, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  134
# results/diabetes/134_153.txt
# Discriminator error:  tensor(1.2956, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6913, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  135
# results/diabetes/135_153.txt
# Discriminator error:  tensor(1.3438, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  136
# results/diabetes/136_153.txt
# Discriminator error:  tensor(1.1334, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  137
# results/diabetes/137_153.txt
# Discriminator error:  tensor(1.3654, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7726, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  138
# results/diabetes/138_153.txt
# Discriminator error:  tensor(1.1009, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9741, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  139
# results/diabetes/139_153.txt
# Discriminator error:  tensor(1.1809, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8553, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  140
# results/diabetes/140_153.txt
# Discriminator error:  tensor(1.3634, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6263, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  141
# results/diabetes/141_153.txt
# Discriminator error:  tensor(1.4134, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7889, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  142
# results/diabetes/142_153.txt
# Discriminator error:  tensor(1.3595, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9119, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  143
# results/diabetes/143_153.txt
# Discriminator error:  tensor(1.2171, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8010, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  144
# results/diabetes/144_153.txt
# Discriminator error:  tensor(1.3224, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7048, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  145
# results/diabetes/145_153.txt
# Discriminator error:  tensor(1.0813, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7145, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  146
# results/diabetes/146_153.txt
# Discriminator error:  tensor(1.2841, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7266, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  147
# results/diabetes/147_153.txt
# Discriminator error:  tensor(1.1658, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8153, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  148
# results/diabetes/148_153.txt
# Discriminator error:  tensor(1.4689, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9748, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  149
# results/diabetes/149_153.txt
# Discriminator error:  tensor(1.4592, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6782, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  150
# results/diabetes/150_153.txt
# Discriminator error:  tensor(1.1515, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0535, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  151
# results/diabetes/151_153.txt
# Discriminator error:  tensor(1.5400, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  152
# results/diabetes/152_153.txt
# Discriminator error:  tensor(1.4214, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  153
# results/diabetes/153_153.txt
# Discriminator error:  tensor(1.7208, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7752, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  154
# results/diabetes/154_153.txt
# Discriminator error:  tensor(1.4217, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  155
# results/diabetes/155_153.txt
# Discriminator error:  tensor(1.3396, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7414, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  156
# results/diabetes/156_153.txt
# Discriminator error:  tensor(1.4454, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9567, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  157
# results/diabetes/157_153.txt
# Discriminator error:  tensor(1.2710, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  158
# results/diabetes/158_153.txt
# Discriminator error:  tensor(1.4284, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  159
# results/diabetes/159_153.txt
# Discriminator error:  tensor(1.1373, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8308, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  160
# results/diabetes/160_153.txt
# Discriminator error:  tensor(1.1991, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5613, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  161
# results/diabetes/161_153.txt
# Discriminator error:  tensor(1.2093, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7095, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  162
# results/diabetes/162_153.txt
# Discriminator error:  tensor(1.6707, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  163
# results/diabetes/163_153.txt
# Discriminator error:  tensor(1.2438, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8284, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  164
# results/diabetes/164_153.txt
# Discriminator error:  tensor(1.3461, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9254, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  165
# results/diabetes/165_153.txt
# Discriminator error:  tensor(1.5000, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9912, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  166
# results/diabetes/166_153.txt
# Discriminator error:  tensor(1.3127, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  167
# results/diabetes/167_153.txt
# Discriminator error:  tensor(1.0986, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8464, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  168
# results/diabetes/168_153.txt
# Discriminator error:  tensor(1.5296, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6396, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  169
# results/diabetes/169_153.txt
# Discriminator error:  tensor(1.1056, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8727, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  170
# results/diabetes/170_153.txt
# Discriminator error:  tensor(1.2880, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6261, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  171
# results/diabetes/171_153.txt
# Discriminator error:  tensor(1.3827, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7415, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  172
# results/diabetes/172_153.txt
# Discriminator error:  tensor(1.4317, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  173
# results/diabetes/173_153.txt
# Discriminator error:  tensor(1.4522, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7433, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  174
# results/diabetes/174_153.txt
# Discriminator error:  tensor(1.5453, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7175, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  175
# results/diabetes/175_153.txt
# Discriminator error:  tensor(0.9400, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7248, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  176
# results/diabetes/176_153.txt
# Discriminator error:  tensor(1.2702, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7413, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  177
# results/diabetes/177_153.txt
# Discriminator error:  tensor(1.2848, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6364, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  178
# results/diabetes/178_153.txt
# Discriminator error:  tensor(1.2615, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8634, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  179
# results/diabetes/179_153.txt
# Discriminator error:  tensor(1.7375, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8038, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  180
# results/diabetes/180_153.txt
# Discriminator error:  tensor(2.0186, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6527, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  181
# results/diabetes/181_153.txt
# Discriminator error:  tensor(1.1598, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  182
# results/diabetes/182_153.txt
# Discriminator error:  tensor(1.2246, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  183
# results/diabetes/183_153.txt
# Discriminator error:  tensor(1.2851, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  184
# results/diabetes/184_153.txt
# Discriminator error:  tensor(1.4122, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  185
# results/diabetes/185_153.txt
# Discriminator error:  tensor(1.4261, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0600, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  186
# results/diabetes/186_153.txt
# Discriminator error:  tensor(0.9531, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7135, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  187
# results/diabetes/187_153.txt
# Discriminator error:  tensor(1.0602, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5547, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  188
# results/diabetes/188_153.txt
# Discriminator error:  tensor(1.3172, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  189
# results/diabetes/189_153.txt
# Discriminator error:  tensor(1.4242, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0116, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  190
# results/diabetes/190_153.txt
# Discriminator error:  tensor(1.3709, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6766, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  191
# results/diabetes/191_153.txt
# Discriminator error:  tensor(1.3059, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7151, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  192
# results/diabetes/192_153.txt
# Discriminator error:  tensor(1.4361, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8338, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  193
# results/diabetes/193_153.txt
# Discriminator error:  tensor(2.0682, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8184, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  194
# results/diabetes/194_153.txt
# Discriminator error:  tensor(1.3302, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7903, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  195
# results/diabetes/195_153.txt
# Discriminator error:  tensor(1.1310, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2626, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  196
# results/diabetes/196_153.txt
# Discriminator error:  tensor(1.5229, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8543, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  197
# results/diabetes/197_153.txt
# Discriminator error:  tensor(1.5072, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.4701, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  198
# results/diabetes/198_153.txt
# Discriminator error:  tensor(1.0518, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  199
# results/diabetes/199_153.txt
# Discriminator error:  tensor(1.4684, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7974, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  200
# results/diabetes/200_153.txt
# Discriminator error:  tensor(1.3910, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  201
# results/diabetes/201_153.txt
# Discriminator error:  tensor(1.3524, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7643, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  202
# results/diabetes/202_153.txt
# Discriminator error:  tensor(0.9010, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6348, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  203
# results/diabetes/203_153.txt
# Discriminator error:  tensor(1.3365, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  204
# results/diabetes/204_153.txt
# Discriminator error:  tensor(1.1516, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.4179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  205
# results/diabetes/205_153.txt
# Discriminator error:  tensor(1.3831, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8493, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  206
# results/diabetes/206_153.txt
# Discriminator error:  tensor(1.4901, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7732, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  207
# results/diabetes/207_153.txt
# Discriminator error:  tensor(1.5844, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8082, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  208
# results/diabetes/208_153.txt
# Discriminator error:  tensor(1.5970, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9184, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  209
# results/diabetes/209_153.txt
# Discriminator error:  tensor(1.4756, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8201, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  210
# results/diabetes/210_153.txt
# Discriminator error:  tensor(1.6098, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7808, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  211
# results/diabetes/211_153.txt
# Discriminator error:  tensor(1.2907, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8564, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  212
# results/diabetes/212_153.txt
# Discriminator error:  tensor(1.6068, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.1316, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  213
# results/diabetes/213_153.txt
# Discriminator error:  tensor(2.8811, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  214
# results/diabetes/214_153.txt
# Discriminator error:  tensor(1.3216, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  215
# results/diabetes/215_153.txt
# Discriminator error:  tensor(1.5231, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6505, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  216
# results/diabetes/216_153.txt
# Discriminator error:  tensor(1.6532, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7800, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  217
# results/diabetes/217_153.txt
# Discriminator error:  tensor(1.8054, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  218
# results/diabetes/218_153.txt
# Discriminator error:  tensor(1.2121, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7955, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  219
# results/diabetes/219_153.txt
# Discriminator error:  tensor(1.3718, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7306, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  220
# results/diabetes/220_153.txt
# Discriminator error:  tensor(1.6668, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5346, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  221
# results/diabetes/221_153.txt
# Discriminator error:  tensor(1.1000, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6694, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  222
# results/diabetes/222_153.txt
# Discriminator error:  tensor(1.5971, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.9393, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  223
# results/diabetes/223_153.txt
# Discriminator error:  tensor(1.6642, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7820, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  224
# results/diabetes/224_153.txt
# Discriminator error:  tensor(1.0190, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8883, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  225
# results/diabetes/225_153.txt
# Discriminator error:  tensor(1.5171, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  226
# results/diabetes/226_153.txt
# Discriminator error:  tensor(1.7889, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7882, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  227
# results/diabetes/227_153.txt
# Discriminator error:  tensor(1.0584, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0712, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  228
# results/diabetes/228_153.txt
# Discriminator error:  tensor(1.7792, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8427, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  229
# results/diabetes/229_153.txt
# Discriminator error:  tensor(1.4099, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8037, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  230
# results/diabetes/230_153.txt
# Discriminator error:  tensor(1.2404, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6473, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  231
# results/diabetes/231_153.txt
# Discriminator error:  tensor(1.6630, device='cuda:0', grad_fn=<ThAddBackward>)
# ...
# Generator error:  tensor(0.7993, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2877
# results/diabetes/2877_153.txt
# Discriminator error:  tensor(1.3792, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.2797, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2878
# results/diabetes/2878_153.txt
# Discriminator error:  tensor(1.2809, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6496, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2879
# results/diabetes/2879_153.txt
# Discriminator error:  tensor(1.2455, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7700, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2880
# results/diabetes/2880_153.txt
# Discriminator error:  tensor(1.5146, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8519, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2881
# results/diabetes/2881_153.txt
# Discriminator error:  tensor(1.4447, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6971, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2882
# results/diabetes/2882_153.txt
# Discriminator error:  tensor(1.4340, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2883
# results/diabetes/2883_153.txt
# Discriminator error:  tensor(1.5306, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2884
# results/diabetes/2884_153.txt
# Discriminator error:  tensor(1.6087, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2885
# results/diabetes/2885_153.txt
# Discriminator error:  tensor(1.4708, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7713, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2886
# results/diabetes/2886_153.txt
# Discriminator error:  tensor(1.1788, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6752, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2887
# results/diabetes/2887_153.txt
# Discriminator error:  tensor(1.3185, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6147, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2888
# results/diabetes/2888_153.txt
# Discriminator error:  tensor(1.3801, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5998, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2889
# results/diabetes/2889_153.txt
# Discriminator error:  tensor(1.6713, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7629, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2890
# results/diabetes/2890_153.txt
# Discriminator error:  tensor(1.4569, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7288, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2891
# results/diabetes/2891_153.txt
# Discriminator error:  tensor(1.4607, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6700, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2892
# results/diabetes/2892_153.txt
# Discriminator error:  tensor(2.4070, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6493, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2893
# results/diabetes/2893_153.txt
# Discriminator error:  tensor(1.2178, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7247, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2894
# results/diabetes/2894_153.txt
# Discriminator error:  tensor(1.3661, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2895
# results/diabetes/2895_153.txt
# Discriminator error:  tensor(1.3549, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7243, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2896
# results/diabetes/2896_153.txt
# Discriminator error:  tensor(1.3584, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6021, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2897
# results/diabetes/2897_153.txt
# Discriminator error:  tensor(1.3011, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2898
# results/diabetes/2898_153.txt
# Discriminator error:  tensor(1.3958, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8499, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2899
# results/diabetes/2899_153.txt
# Discriminator error:  tensor(1.4196, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2900
# results/diabetes/2900_153.txt
# Discriminator error:  tensor(1.2957, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7710, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2901
# results/diabetes/2901_153.txt
# Discriminator error:  tensor(1.4674, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7636, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2902
# results/diabetes/2902_153.txt
# Discriminator error:  tensor(1.2807, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8825, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2903
# results/diabetes/2903_153.txt
# Discriminator error:  tensor(1.2705, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6846, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2904
# results/diabetes/2904_153.txt
# Discriminator error:  tensor(1.5699, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5369, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2905
# results/diabetes/2905_153.txt
# Discriminator error:  tensor(1.2812, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6997, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2906
# results/diabetes/2906_153.txt
# Discriminator error:  tensor(1.3046, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6206, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2907
# results/diabetes/2907_153.txt
# Discriminator error:  tensor(1.5058, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7567, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2908
# results/diabetes/2908_153.txt
# Discriminator error:  tensor(1.4577, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2909
# results/diabetes/2909_153.txt
# Discriminator error:  tensor(1.4244, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8307, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2910
# results/diabetes/2910_153.txt
# Discriminator error:  tensor(1.3076, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7267, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2911
# results/diabetes/2911_153.txt
# Discriminator error:  tensor(1.3336, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8150, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2912
# results/diabetes/2912_153.txt
# Discriminator error:  tensor(1.1634, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2913
# results/diabetes/2913_153.txt
# Discriminator error:  tensor(1.8227, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7979, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2914
# results/diabetes/2914_153.txt
# Discriminator error:  tensor(1.2847, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2915
# results/diabetes/2915_153.txt
# Discriminator error:  tensor(1.4494, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6785, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2916
# results/diabetes/2916_153.txt
# Discriminator error:  tensor(1.4002, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6955, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2917
# results/diabetes/2917_153.txt
# Discriminator error:  tensor(1.6060, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8441, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2918
# results/diabetes/2918_153.txt
# Discriminator error:  tensor(1.1933, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7982, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2919
# results/diabetes/2919_153.txt
# Discriminator error:  tensor(1.4103, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2920
# results/diabetes/2920_153.txt
# Discriminator error:  tensor(1.1211, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6500, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2921
# results/diabetes/2921_153.txt
# Discriminator error:  tensor(1.4019, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2922
# results/diabetes/2922_153.txt
# Discriminator error:  tensor(1.5705, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7427, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2923
# results/diabetes/2923_153.txt
# Discriminator error:  tensor(1.4221, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2924
# results/diabetes/2924_153.txt
# Discriminator error:  tensor(1.4509, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8715, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2925
# results/diabetes/2925_153.txt
# Discriminator error:  tensor(1.3646, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7092, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2926
# results/diabetes/2926_153.txt
# Discriminator error:  tensor(1.0611, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2927
# results/diabetes/2927_153.txt
# Discriminator error:  tensor(1.2345, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(1.0215, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2928
# results/diabetes/2928_153.txt
# Discriminator error:  tensor(1.3840, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8707, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2929
# results/diabetes/2929_153.txt
# Discriminator error:  tensor(1.4930, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6673, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2930
# results/diabetes/2930_153.txt
# Discriminator error:  tensor(1.2575, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7432, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2931
# results/diabetes/2931_153.txt
# Discriminator error:  tensor(1.4211, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6357, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2932
# results/diabetes/2932_153.txt
# Discriminator error:  tensor(1.4171, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2933
# results/diabetes/2933_153.txt
# Discriminator error:  tensor(1.4933, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7228, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2934
# results/diabetes/2934_153.txt
# Discriminator error:  tensor(1.3839, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7282, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2935
# results/diabetes/2935_153.txt
# Discriminator error:  tensor(1.3086, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6640, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2936
# results/diabetes/2936_153.txt
# Discriminator error:  tensor(1.5008, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7247, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2937
# results/diabetes/2937_153.txt
# Discriminator error:  tensor(1.3853, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6575, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2938
# results/diabetes/2938_153.txt
# Discriminator error:  tensor(1.2343, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6263, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2939
# results/diabetes/2939_153.txt
# Discriminator error:  tensor(1.4352, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2940
# results/diabetes/2940_153.txt
# Discriminator error:  tensor(1.4327, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6912, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2941
# results/diabetes/2941_153.txt
# Discriminator error:  tensor(1.2812, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7740, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2942
# results/diabetes/2942_153.txt
# Discriminator error:  tensor(1.5623, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.8655, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2943
# results/diabetes/2943_153.txt
# Discriminator error:  tensor(1.5110, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2944
# results/diabetes/2944_153.txt
# Discriminator error:  tensor(1.5023, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5239, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2945
# results/diabetes/2945_153.txt
# Discriminator error:  tensor(1.4377, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7610, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2946
# results/diabetes/2946_153.txt
# Discriminator error:  tensor(1.3534, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.5128, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2947
# results/diabetes/2947_153.txt
# Discriminator error:  tensor(1.2819, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7348, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2948
# results/diabetes/2948_153.txt
# Discriminator error:  tensor(1.2972, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6570, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2949
# results/diabetes/2949_153.txt
# Discriminator error:  tensor(1.5905, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7352, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2950
# results/diabetes/2950_153.txt
# Discriminator error:  tensor(1.3252, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.7390, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2951
# results/diabetes/2951_153.txt
# Discriminator error:  tensor(1.3731, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:  tensor(0.6286, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
#
# Epoch  2952
# results/diabetes/2952_153.txt
# Discriminator error:  tensor(1.1128, device='cuda:0', grad_fn=<ThAddBackward>)
# Generator error:

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + file_name[:-4] + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()
plt.show()

# %%
points_collection = []
for batch in generated_points:
    if batch[0].size() != []:
        for point in batch:
            point = point.cpu().detach().numpy()
            points_collection.append(point)

# %%
df = pd.DataFrame(points_collection, columns=database.get_columns()).round(2)
df.to_csv( "fake_data/" + file_name[:-4] + "_" + str(epoch) + ".csv")
